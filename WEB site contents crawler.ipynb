# %% [markdown]
# ## WEB site contents crawler
# 자원봉사 사이트에서 컨텐츠를 가져오기 위한 코드다.

# %%
# 만약 개발자버전 확인할 수 없기 때문에... 라는 메시지가 실행 시 나오면 'xattr -d com.apple.quarantine chromedriver'를 터미널에서 실행할 것
from selenium import webdriver
browser = webdriver.Chrome('/Users/kimkwangil/Documents/social_volunteer_recommendation_ai/chromedriver')
browser.implicitly_wait(3)
# url에 접근한다.
browser.set_window_size(1920, 1280)

# 정보를 추출할 웹사이트 링크를 입력한다. 그러면 웹브라우저가 실행된다.이것은 selenium에 의해서 제어되는 웹이다.
# 여기서는 https://www.volunteermatch.org/의 결과를 가지고 분석해볼 수 있겠다.

browser.get('https://www.volunteermatch.org/search/opp1781779.jsp')

# %%
ls
# Out:
# Massachusetts_volunteermatch_data.txt  WEB site contents crawler.ipynb*
# THEME_/                                chromedriver*
# Untitled.ipynb*                        chromedriver_mac64.zip

# %%
# 추출된 내용을 확인할 수 있다.
print('source : {}'.format(browser.page_source))
# Out:
# source : <html class="wf-montserrat-n3-active wf-montserrat-n2-active wf-montserrat-i2-active wf-montserrat-i3-active wf-montserrat-n4-active wf-montserrat-i4-active wf-montserrat-n5-active wf-montserrat-n6-active wf-active"><head><style>.gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1){display:none}.gm-control-active:hover>img:nth-child(2),.gm-control-active:active>img:nth-child(3){display:block}
# </style><style>.gm-ui-hover-effect{opacity:.6}.gm-ui-hover-effect:hover{opacity:1}
# </style><style>.gm-style .gm-style-cc span,.gm-style .gm-style-cc a,.gm-style .gm-style-mtc div{font-size:10px;box-sizing:border-box}
# ...

# %%
#세부정보확인
print('Session ID: {}'.format(browser.session_id))
print('Title : {}'.format(browser.title))
print('URL : {}'.format(browser.current_url))
print('Cookies : {}'.format(browser.get_cookies))
# Out:
# Session ID: d351c0b690cf22bcd9e7417ff087ba69
# Title : FRIENDLY VISITOR PROGRAM: South Shore Elder Services, Inc. Opportunity - VolunteerMatch
# URL : https://www.volunteermatch.org/search/opp1781779.jsp
# Cookies : <bound method WebDriver.get_cookies of <selenium.webdriver.chrome.webdriver.WebDriver (session="d351c0b690cf22bcd9e7417ff087ba69")>>

# %% [markdown]
# 웹페이지에 접속해서 text 를 긁어오는 코드 >> urlopen에 웹주소를 붙이고 실행하면 텍스트파일로 자동 저장됨

# %%
import urllib.request
import urllib.parse
from bs4 import BeautifulSoup
from html.parser import HTMLParser

with urllib.request.urlopen('https://www.volunteermatch.org/search/opp1781779.jsp') as response:
    html = response.read()
    soup = BeautifulSoup(html, 'html.parser')
    all_divs = soup.find_all("p")
    #print(all_divs)
    
    interviews = []
    for interview in all_divs:
        interviews.append(interview.get_text().strip().replace('\n', '').replace('\t', '').replace('\r', ''))
    
    file = open("FRIENDLY VISITOR PROGRAM_data.txt", 'w', encoding="utf-8")
    

    
    for i in interviews:
        file.write(i + "\n")
    
    print(i)
    file.close()
# Out:
# © 1998-2021 VolunteerMatch. A 501(C)(3) Organization. EIN: 77-0395654. All Rights Reserved.Privacy Policy  /  Terms of Use

# %% [markdown]
# 추출한 정보를 가져올 수 있다. 이러한 내용을 토대로 데이터베이스를 만들어서, 이력서 분석 후 매칭 솔루션을 만들 수 있다.

# %%
from collections import Counter

file = open('FRIENDLY VISITOR PROGRAM_data.txt', 'r', encoding = 'utf-8')
lines = file.readlines()
lines
# Out:
# ['Save to Favorites\n',
#  'South Shore Elder Services, Inc.\n',
#  "BRING A SMILE TO A LONELY ELDER OR YOUNGER DISABLED PERSON'S LIFE. VISIT ONCE WEEKLY FOR 1-2 HOURS AND BRIGHTEN SOMEONE'S DAY. MAKE A NEW FRIEND AND FEEL GREAT ABOUT IT!\n",
#  'MILEAGE REIMBURSEMENT IS AVAILABLE.\n',
#  'THIS IS A VERY REWARDING OPPORTUNITY!\n',
#  '1515 Washington St., Braintree, MA  02184, US\n',
#  'To promote and maintain an optimal level of elder independence through coordination of resources, advocacy, and caregiver support.\n',
# ...
